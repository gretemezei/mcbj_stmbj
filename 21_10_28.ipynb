# %% [markdown]
# # 2021.10.28.
# ## STM measurements

# %%
from mcbj import *
import plots
import filter_traces

import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, StrMethodFormatter
import numpy as np
# import pandas as pd

# %%
date = "21_10_28"
home_folder = Path(f'//DATACENTER/BreakJunction_group/BJ_Data/{date}')

# %%
hist = Histogram(folder=home_folder,
                 start_trace=801,end_trace=900,
                 conductance_range=(1e-5, 10),
                 conductance_log_scale=True,
                 conductance_bins_num=100,
                 conductance_bins_mode='total')

hist.calc_stats(align_at=0.5, interpolate=True,
                range_pull=(-0.5, 1),
                range_push=(-0.5, 1.5))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Pull 2D histogram created from 100 traces
# Push 2D histogram created from 100 traces

# %%
ax = hist.plot_hist_1d(dpi=200)
ax.set_ylim(0, 250)
ax.axvline(1, ls='--', lw=0.5, c='r')

# %%
hist = Histogram(folder=home_folder,
                 start_trace=901, end_trace=1000,
                 conductance_range=(1e-5, 10),
                 conductance_log_scale=True,
                 conductance_bins_num=100,
                 conductance_bins_mode='total')

hist.calc_stats(align_at=0.5, interpolate=True,
                range_pull=(-0.5, 1),
                range_push=(-0.5, 1.5))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Pull 2D histogram created from 100 traces
# Push 2D histogram created from 100 traces

# %%
ax = hist.plot_hist_1d(dpi=200)
ax.set_ylim(0, 100)
ax.axvline(1, ls='--', lw=0.5, c='r')

# %%
hist = Histogram(folder=home_folder,
                 start_trace=1001, end_trace=10000,
                 conductance_range=(1e-5, 10),
                 conductance_log_scale=True,
                 conductance_bins_num=100,
                 conductance_bins_mode='total')

hist.calc_stats(align_at=0.5, interpolate=True,
                range_pull=(-0.5, 1),
                range_push=(-0.5, 1.5))
# Out:
#   0%|          | 0/9000 [00:00<?, ?it/s]
# Pull 2D histogram created from 9000 traces
# Push 2D histogram created from 9000 traces

# %%
ax = hist.plot_hist_1d(dpi=200)
ax.set_ylim(0, 500)
ax.axvline(1, ls='--', lw=0.5, c='r')

# %%
utils.convert_ohm_to_g0(10000)
# Out:
# 1.29
