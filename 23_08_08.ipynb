# %% [markdown]
# # 2023.08.08
# ## STM Measurements

# %%
from mcbj import *
import plots
import filter_traces

import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, StrMethodFormatter
import numpy as np
# import pandas as pd

# %%
date = "23_08_08"
home_folder = Path(f'//DATACENTER/BreakJunction_group/BJ_Data/{date}')

# %%
my_colors = np.vstack((colormaps['inferno'](np.linspace(0.2, 1, 7)[0]),
                       np.array([[0, 0, 0, 1]]),
                       colormaps['inferno'](np.linspace(0.2, 1, 7)),
                       np.array(colormaps['inferno'](np.linspace(0.2, 1, 7)))[[-2, -3, -5, -7]]))

# %%
hist = Histogram(folder=home_folder,
                 start_trace=1, end_trace=100,
                 conductance_range=(1e-5, 10),
                 conductance_log_scale=True,
                 conductance_bins_num=100,
                 conductance_bins_mode='total')

hist.calc_stats(align_at=0.5, interpolate=True,
                range_pull=(-0.5, 1),
                range_push=(-0.5, 1.5))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# D:\mcbj_stmbj\utils.py:951: RuntimeWarning: divide by zero encountered in double_scalars
#   return ind1[0] + (y - ind1[1]) * (ind2[0] - ind1[0]) / (ind2[1] - ind1[1])
# Pull 2D histogram created from 100 traces
# Push 2D histogram created from 100 traces

# %%
ax = hist.plot_hist_1d(dpi=200)
ax.set_ylim(0, 500)
# Out:
# (0.0, 500.0)

# %%
ax=hist.plot_hist_2d_both(dpi=200)

# %%
hist.calc_hist_2d(align_at=1e-5)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# 2D histogram pull direction created from 100 traces
# 2D histogram push direction created from 100 traces

# %%
ax=hist.plot_hist_2d_both(dpi=200)

# %%
hist.plot_temporal_hist(dpi=200, vmax_pull=500, vmax_push=1000)
# Out:
# (<AxesSubplot:xlabel='Trace number', ylabel='Conductance $[G_{0}]$'>,
#  <AxesSubplot:xlabel='Trace number', ylabel='Conductance $[G_{0}]$'>)

# %%
hist.calc_corr_hist_2d()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
hist.plot_corr('cross', dpi=200)
plt.savefig(home_folder.joinpath('pull_corr_2d_fig.png'), bbox_inches='tight', dpi=600)

# %%
trace_pair=TracePair(load_from=home_folder, trace=75)

# %%
print(trace_pair.align_at)
# Out:
# None

# %%
trace_pair.align_trace(0.5)
print(trace_pair.align_at)
ax = trace_pair.plot_trace_pair(dpi=200)
# ax.set_xlim(37, 38)
# Out:
# 0.5

# %%
trace_pair.
