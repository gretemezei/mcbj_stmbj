# %%
from mcbj import *

date = "21_12_01"
sample_rate = 50_000
home_folder = Path(f"D:/BJ_Data/{date}")

# %%
hist_1 = Histogram(home_folder, 1, 7300)

hist_1.calc_stats(align_at=1e-5, range_pull=(-1.5, 1), range_push=(-3, 1), xbins_pull=250, xbins_push=400,
                  plateau_length_bins=100)
# Out:
# 100%|██████████| 74/74 [17:51<00:00, 14.48s/it]
# Pull 2D histogram created from 7300 traces
# Push 2D histogram created from 7300 traces

# %%
hist_1.plot_temporal_hist()
hist_1.plot_hist_1d(ylims=(0, 150))
hist_1.plot_hist_2d_both(cmap=hist_1.cmap_geo32)
hist_1.plot_plateau_length_hist()
# Out:
# <AxesSubplot:xlabel='Plateau length [points]', ylabel='Counts [a.u.]'>

# %%
hist_2 = Histogram(home_folder, 21501, 23210)

hist_2.calc_stats(align_at=1e-5, range_pull=(-1.5, 1), range_push=(-3, 1), xbins_pull=250, xbins_push=400,
                  plateau_length_bins=100)
# Out:
# 100%|██████████| 18/18 [04:12<00:00, 14.01s/it]
# Pull 2D histogram created from 1709 traces
# Push 2D histogram created from 1709 traces

# %%
hist_2.plot_temporal_hist()
hist_2.plot_hist_1d(ylims=(0, 150))
hist_2.plot_hist_2d_both(cmap=hist_1.cmap_geo32)
hist_2.plot_plateau_length_hist()
# Out:
# <AxesSubplot:xlabel='Plateau length [points]', ylabel='Counts [a.u.]'>
